# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/barbara/Documentos/datos/tarea/AnalisisGuia2/ufo-sightings/scrubbed.csv')

# %%
 data.tail()
# Out:
#              datetime       city state country   shape duration (seconds)  \
# 80327  9/9/2013 21:15  nashville    tn      us   light                600
# 80328  9/9/2013 22:00      boise    id      us  circle               1200
# 80329  9/9/2013 22:00       napa    ca      us   other               1200
# 80330  9/9/2013 22:20     vienna    va      us  circle                  5
# 80331  9/9/2013 23:00     edmond    ok      us   cigar               1020
#
#       duration (hours/min)                                           comments  \
# 80327           10 minutes  Round from the distance/slowly changing colors...
# 80328           20 minutes  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 80329                 hour                                       Napa UFO&#44
# 80330            5 seconds  Saw a five gold lit cicular craft moving fastl...
# 80331           17 minutes  2 witnesses 2  miles apart&#44 Red &amp; White...
#
#       date posted latitude  longitude
# ...

# %%
data_idx = data.index
data_idx
# Out:
# RangeIndex(start=0, stop=80332, step=1)

# %%
data_col = data.columns
data_col
# Out:
# Index([u'datetime', u'city', u'state', u'country', u'shape',
#        u'duration (seconds)', u'duration (hours/min)', u'comments',
#        u'date posted', u'latitude', u'longitude '],
#       dtype='object')

# %%
data_values = data.values
data_values
# Out:
# array([['10/10/1949 20:30', 'san marcos', 'tx', ..., '4/27/2004',
#         '29.8830556', -97.94111109999999],
#        ['10/10/1949 21:00', 'lackland afb', 'tx', ..., '12/16/2005',
#         '29.38421', -98.581082],
#        ['10/10/1955 17:00', 'chester (uk/england)', nan, ...,
#         '1/21/2008', '53.2', -2.916667],
#        ...,
#        ['9/9/2013 22:00', 'napa', 'ca', ..., '9/30/2013', 38.2972222,
#         -122.28444440000001],
#        ['9/9/2013 22:20', 'vienna', 'va', ..., '9/30/2013', 38.9011111,
#         -77.2655556],
#        ['9/9/2013 23:00', 'edmond', 'ok', ..., '9/30/2013', 35.6527778,
#         -97.4777778]], dtype=object)

# %%
data.head(10)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
# 5  10/10/1961 19:00               bristol    tn      us    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)   NaN      gb    circle
# 7  10/10/1965 23:45               norwalk    ct      us      disk
# 8  10/10/1966 20:00             pell city    al      us      disk
# 9  10/10/1966 21:00              live oak    fl      us      disk
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
estados=data['state']
estados.value_counts().head(10)
# Out:
# ca    9655
# wa    4268
# fl    4200
# tx    3677
# ny    3219
# az    2689
# il    2645
# pa    2582
# oh    2425
# mi    2071
# Name: state, dtype: int64

# %%
paises=data['country']
paises.value_counts().head(10)
# Out:
# us    65114
# ca     3000
# gb     1905
# au      538
# de      105
# Name: country, dtype: int64

# %%
# analizemos primero las dimensiones del data frame
print(data.shape)
# Out:
# (80332, 11)

# %%
# veamos la informacion general del dataframe con info()
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime                80332 non-null object
# city                    80332 non-null object
# state                   74535 non-null object
# country                 70662 non-null object
# shape                   78400 non-null object
# duration (seconds)      80332 non-null object
# duration (hours/min)    80332 non-null object
# comments                80317 non-null object
# date posted             80332 non-null object
# latitude                80332 non-null object
# longitude               80332 non-null float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB
# None

# %%
comentarios = data['comments']

# %%
comentarios.value_counts()
# Out:
# Fireball                                                                                                                                           11
# ((NUFORC Note:  No information provided by witness.  PD))                                                                                           9
# Lights in the sky                                                                                                                                   7
# ((NUFORC Note:  Witness provides no information.  PD))                                                                                              7
# UFO                                                                                                                                                 7
# lights in the sky                                                                                                                                   6
# ...

# %%
data['posted_datetime'] = pd.to_datetime(data['date posted'])
data['year'] = data['posted_datetime'].dt.year

# %%
data['year'].value_counts()
# Out:
# 2012    8090
# 2013    7562
# 2009    5936
# 2011    5616
# 2005    5288
# 2004    5224
# 2008    5121
# 2007    4875
# 2003    4792
# 2010    4446
# 2006    4399
# 1999    4286
# 2002    4230
# 2001    3496
# 2000    3042
# 2014    3039
# 1998     890
# Name: year, dtype: int64

# %%
# por ejemplo de la siguiente forma podemos ver los nulos si existen
data.isnull().any()
# Out:
# datetime                False
# city                    False
# state                    True
# country                  True
# shape                    True
# duration (seconds)      False
# duration (hours/min)    False
# comments                 True
# date posted             False
# latitude                False
# longitude               False
# posted_datetime         False
# year                    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date posted                0
# latitude                   0
# longitude                  0
# posted_datetime            0
# year                       0
# dtype: int64

# %%
data.describe()
# Out:
#          longitude           year
# count  80332.000000  80332.000000
# mean     -86.772885   2007.054237
# std       39.697205      4.543342
# min     -176.658056   1998.000000
# 25%     -112.073333   2003.000000
# 50%      -87.903611   2007.000000
# 75%      -78.755000   2011.000000
# max      178.441900   2014.000000

# %%
# para visualizar toda la informacion
data.describe(include='all')
# Out:
#               datetime     city  state country  shape duration (seconds)  \
# count            80332    80332  74535   70662  78400              80332
# unique           69586    19900     67       5     29                706
# top     7/4/2010 22:00  seattle     ca      us  light                300
# freq                36      525   9655   65114  16565               7070
# mean               NaN      NaN    NaN     NaN    NaN                NaN
# std                NaN      NaN    NaN     NaN    NaN                NaN
# min                NaN      NaN    NaN     NaN    NaN                NaN
# 25%                NaN      NaN    NaN     NaN    NaN                NaN
# 50%                NaN      NaN    NaN     NaN    NaN                NaN
# 75%                NaN      NaN    NaN     NaN    NaN                NaN
# max                NaN      NaN    NaN     NaN    NaN                NaN
#
#        duration (hours/min)  comments date posted    latitude    longitude
# ...

# %%
data1 = data[data['state'] == 'ca']

# %%
data1.tail()
# Out:
#              datetime       city state country      shape duration (seconds)  \
# 80299  9/9/2012 20:00     arcata    ca      us  formation                600
# 80305  9/9/2012 20:30    ventura    ca      us    chevron                900
# 80310  9/9/2012 21:00    ventura    ca      us     circle                300
# 80316  9/9/2013 09:51  san diego    ca      us      light                  4
# 80329  9/9/2013 22:00       napa    ca      us      other               1200
#
#       duration (hours/min)                                           comments  \
# 80299           10 minutes  Object with red and green lights moving sited ...
# 80305           15 minutes     Beautiful bright blue delta shaped aerobatics.
# 80310            5 minutes  Bright Blue Object seen floating in sky near C...
# 80316           ~4 seconds  2 white lights zig-zag over Qualcomm Stadium (...
# 80329                 hour                                       Napa UFO&#44
#
# ...

# %%
#Cuantos avistajes en el 2000 en estados unidos
data_filter = data[data['country'] == 'us']

data_filter = data_filter[data_filter['year']== 2000]

data_filter.tail()
# Out:
#              datetime          city state country     shape  \
# 80138  9/9/2000 20:30    alamogordo    nm      us      disk
# 80139  9/9/2000 21:30     hermitage    pa      us  triangle
# 80140  9/9/2000 21:30     white oak    ms      us  fireball
# 80141  9/9/2000 22:15  johannesburg    mi      us  fireball
# 80142  9/9/2000 22:30     dahlonega    ga      us  changing
#
#       duration (seconds) duration (hours/min)  \
# 80138                300            5 minutes
# 80139                 15         10-15seconds
# 80140                 20                20sec
# 80141                600           10 minutes
# 80142               3600      at least 1 hour
#
#                                                 comments date posted latitude  \
# 80138  Grey Metallic Aircraft Floating Behind the Clo...   12/2/2000  32.8994
# 80139  On 09/09/2000 I saw an object that had three r...   9/17/2000  41.2333
# 80140  fireball with small round object leaving it af...   12/2/2000  34.4908
# ...

# %%
data_filter_idx = data_filter.index
data_filter_idx
#2323 avistajes en estados unidos en el año 2000
# Out:
# Int64Index([   12,    64,    93,    94,    98,    99,   283,   287,   322,
#               323,
#             ...
#             80132, 80133, 80134, 80136, 80137, 80138, 80139, 80140, 80141,
#             80142],
#            dtype='int64', length=2323)

# %%
# reportes de cuantos paises?
paises=data['country']
paises.value_counts()

#5 paises distintos
# Out:
# us    65114
# ca     3000
# gb     1905
# au      538
# de      105
# Name: country, dtype: int64

# %%
# que forma tienen?
data_filter = data[data['shape'] == 'chevron']
data_filter_idx = data_filter.index
data_filter_idx

#952 con forma de chevron
# Out:
# Int64Index([   28,    40,    91,   267,   292,   346,   397,   431,   453,
#               471,
#             ...
#             79230, 79450, 79489, 79551, 79970, 80061, 80115, 80154, 80236,
#             80305],
#            dtype='int64', length=952)

# %%
#La forma con mayor cantidad de registros en Los Angeles, CA es la forma de triangulo. ???

data_filter = data[data['city'] == 'los angeles']


data_filter = data_filter['shape']
data_filter.value_counts()

#light mayor forma avistada en los angeles
# Out:
# light        63
# circle       36
# triangle     30
# fireball     29
# disk         29
# unknown      26
# sphere       25
# other        21
# cigar        16
# oval         16
# changing     14
# formation    11
# rectangle     5
# chevron       5
# egg           5
# flash         5
# diamond       4
# teardrop      4
# cone          3
# cylinder      1
# Name: shape, dtype: int64

# %%
#La ciudad de Vancouver en Canadá tiene un registro en el Top20 de avistajes de mayor duración en Segundos??

df3 = data.loc[:, ['city', 'duration (seconds)']]
df3['duration (seconds)'] = pd.to_numeric(data['duration (seconds)'], errors='coerce')
df3 = df3.sort_values(by=['duration (seconds)'], ascending=False)

df3.head(20)

         

#falso
# Out:
#                                    city  duration (seconds)
# 559             birmingham (uk/england)          97836000.0
# 53384                   ottawa (canada)          82800000.0
# 74660                        greenbrier          66276000.0
# 64390                            finley          52623200.0
# 38261                         dont know          52623200.0
# 69215                         englewood          52623200.0
# 52709             somerset (uk/england)          25248000.0
# 71172                    virginia beach          10526400.0
# 6991                           oklahoma          10526400.0
# 30596                           menifee          10526400.0
# 10853                        new canaan           9468000.0
# 54009       mostar (bosnia/herzogovina)           9468000.0
# 31486                           griffin           7894800.0
# 53006                          honolulu           6312000.0
# 30590                            ganado           6312000.0
# ...

# %%
# La forma mas común en los ufos registrados es circular?
data_filter = data['shape']
data_filter.value_counts()
#data_filter.head()

#la forma mas comun es light
# Out:
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# crescent         2
# round            2
# flare            1
# pyramid          1
# dome             1
# hexagon          1
# changed          1
# Name: shape, dtype: int64

# %%
# El estado con mas avistajes de ovnis es California?
estados=data['state']
estados.value_counts()
#true
# Out:
# ca    9655
# wa    4268
# fl    4200
# tx    3677
# ny    3219
# az    2689
# il    2645
# pa    2582
# oh    2425
# mi    2071
# nc    1869
# or    1845
# on    1584
# mo    1576
# nj    1512
# co    1505
# va    1393
# in    1386
# ma    1358
# ga    1347
# wi    1333
# tn    1193
# mn    1081
# sc    1076
# ct     968
# ky     914
# md     911
# nv     905
# nm     815
# bc     788
#       ...
# la     598
# id     554
# nh     535
# mt     510
# wv     486
# ms     415
# ne     405
# ak     354
# hi     353
# ab     333
# vt     307
# ri     290
# wy     205
# sd     196
# de     183
# qc     178
# mb     155
# ns     143
# nd     138
# nb     116
# dc      99
# sk      98
# pq      90
# pr      33
# sa      30
# nf      25
# nt      20
# pe      17
# yt      13
# yk       7
# Name: state, Length: 67, dtype: int64

# %%
# El promedio de duración de los ufos con formas cambiantes es superior al resto. 
# Ok 
df2 = data.loc[:, ['shape', 'duration (seconds)']] 
df2['duration (seconds)'] = pd.to_numeric(df2['duration (seconds)'], errors='coerce')
df2 = df2.groupby('shape').agg({'duration (seconds)':['mean']})
df2
# Out:
#           duration (seconds)
#                         mean
# shape
# changed          3600.000000
# changing         2079.513405
# chevron           460.317174
# cigar            1917.106830
# circle           4768.092717
# cone            82827.405063
# crescent        18905.000000
# cross             748.519313
# cylinder         3426.512471
# delta            2307.857143
# diamond          1413.628625
# disk             1460.431677
# dome                2.000000
# egg              1886.793281
# fireball         4023.941484
# flare              30.000000
# flash            5330.289421
# formation        1254.048547
# hexagon           240.000000
# light           13170.345373
# other           20634.210977
# oval             3898.586311
# pyramid           120.000000
# rectangle         683.183346
# round             452.500000
# sphere          21787.298238
# teardrop          942.946000
# triangle         1664.266397
# unknown          5546.723104

# %%
# otro csv - ALCOHOL EN LAS ESCUELAS?


data_sa = pd.read_csv('/home/barbara/Documentos/datos/tarea/AnalisisGuia2/student-alcohol-consumption/student-por.csv')
data_sa
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
#Los alumnos cuyas familias están compuestas por mas de tres personas tienen mejor rendimiento académico.?
# Cuales serian las notas, o el rendimiento academico, cual es el "family size" y si es famsize por que es object!
data_sa.dtypes

# vi que era true en el enunciado
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# El consumo de alcohol durante los fines de 
# semana tiene mas influencia en la salud de los alumnos que en el tiempo de estudio.

data_saj = data_sa.loc[:, ['school','failures']]
data_saj
# Out:
#     school  failures
# 0       GP         0
# 1       GP         0
# 2       GP         0
# 3       GP         0
# 4       GP         0
# 5       GP         0
# 6       GP         0
# 7       GP         0
# 8       GP         0
# 9       GP         0
# 10      GP         0
# 11      GP         0
# 12      GP         0
# 13      GP         0
# 14      GP         0
# 15      GP         0
# 16      GP         0
# 17      GP         0
# 18      GP         3
# 19      GP         0
# 20      GP         0
# 21      GP         0
# 22      GP         0
# 23      GP         0
# 24      GP         0
# 25      GP         0
# 26      GP         0
# 27      GP         0
# 28      GP         0
# 29      GP         0
# ..     ...       ...
# 619     MS         0
# 620     MS         0
# 621     MS         0
# 622     MS         0
# 623     MS         0
# 624     MS         1
# 625     MS         0
# 626     MS         0
# 627     MS         0
# 628     MS         0
# 629     MS         0
# ...

# %%
#Realizando un histograma de notas finales, 
#se puede observar que existen mas notas entre 12 y 14 que entre 10 y 12. FALSO
# http://rstudio-pubs-static.s3.amazonaws.com/239994_35cdbafe9de74fc3b7a41b63d249f9f3.html#1_get_our_data

#padres y madres tienen el mismo trabajo y el pibe tiene mejor rendimiento

data_sa_filtrado = data_sa[data_sa['Mjob'] != 'other']
data_sa_filtrado = data_sa[data_sa['Fjob'] != 'other']
data_sas = data_sa_filtrado[data_sa_filtrado['Mjob']== data_sa_filtrado['Fjob']]
data_sas = (data_sas['G1']+ data_sas['G2']+ data_sas['G3'])/3
data_sas.mean()
# Out:
# 12.081699346405232

# %%
data_sa_filtrado = data_sa[data_sa['Mjob'] != 'other']
data_sa_filtrado = data_sa[data_sa['Fjob'] != 'other']
data_sas = data_sa_filtrado[data_sa_filtrado['Mjob'] != data_sa_filtrado['Fjob']]
data_sas = (data_sas['G1']+ data_sas['G2']+ data_sas['G3'])/3
data_sas.sort_values(ascending=False).mean()
# Out:
# 11.42037037037037
